# %% [markdown]
# # Kaggle SSH Tunnel Setup (ngrok)
#
# This notebook establishes an SSH tunnel to the Kaggle VM using ngrok, allowing remote development via VS Code/Cursor Remote-SSH extension.
#
# ## Prerequisites
#
# 1. **Kaggle Secrets** configured in Account Settings:
#    - `DVC_SERVICE_ACCOUNT_JSON`: Google Service Account JSON
#    - `WANDB_API_KEY`: Weights & Biases API key
#    - `NGROK_TOKEN`: ngrok authentication token
#
# 2. **GPU** enabled for this notebook
#
# 3. **Internet** enabled for this notebook
#
# ## Usage
#
# 1. Run all cells in order
# 2. Copy the SSH command and password from Cell 4 output
# 3. Connect via SSH from your local machine (password is randomly generated per session)
# 4. Or use VS Code/Cursor Remote-SSH extension
# 5. Keep this notebook running throughout your training session
#
# ## Security Note
#
# - SSH password is **randomly generated** each session for security
# - Save the password from Cell 4 output immediately
# - Password changes every time you restart the notebook

# %% [markdown]
# ## Cell 1: Install ngrok

# %%
print("Installing ngrok...")
# !wget -q https://bin.equinox.io/c/bNyj1mQVY4c/ngrok-v3-stable-linux-amd64.tgz
# !tar xzf ngrok-v3-stable-linux-amd64.tgz -C /usr/local/bin
# !rm ngrok-v3-stable-linux-amd64.tgz
# !ngrok version
print("✓ ngrok installed")
# Out:
# Installing ngrok...
# ngrok version 3.34.0
# ✓ ngrok installed

# %% [markdown]
# ## Cell 2: Setup SSH Service

# %%
print("Setting up SSH service...")
import subprocess
import secrets

# Install SSH server
# !apt-get update -qq && apt-get install -y -qq openssh-server > /dev/null

# Generate random SSH password per session (store globally for later cells)
SSH_PASSWORD = secrets.token_urlsafe(16)

# Configure SSH
# !echo "root:{SSH_PASSWORD}" | chpasswd
# !echo "PermitRootLogin yes" >> /etc/ssh/sshd_config
# !echo "PasswordAuthentication yes" >> /etc/ssh/sshd_config

# Start service
# !service ssh restart

print("✓ SSH service started on port 22")
print(f"🔐 SSH Password (save this!): {SSH_PASSWORD}")
print("⚠️  Password is randomly generated each session for security")
# Out:
# Setting up SSH service...
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
#  * Restarting OpenBSD Secure Shell server sshd
#    ...done.
# ✓ SSH service started on port 22
# 🔐 SSH Password (save this!): onb4l44pb5PHr9Eq0GNvQw
# ⚠️  Password is randomly generated each session for security

# %% [markdown]
# ## Cell 3: Inject Kaggle Secrets as Environment Variables

# %%
print("Injecting Kaggle Secrets as environment variables...")
import os

# ✅ CORRECT WAY: Use kaggle_secrets to access Kaggle Secrets
from kaggle_secrets import UserSecretsClient

user_secrets = UserSecretsClient()

# Read secrets using Kaggle Secrets API
# Note: Secret names must match exactly what you set in Kaggle Account Settings
try:
    dvc_json = user_secrets.get_secret("DVC_SERVICE_ACCOUNT_JSON")
    print(f"✓ DVC_SERVICE_ACCOUNT_JSON loaded: {len(dvc_json)} characters")
except Exception as e:
    print(f"❌ Error loading DVC_SERVICE_ACCOUNT_JSON: {e}")
    print("   Make sure you've added this secret in Kaggle Account Settings")
    dvc_json = ""

try:
    wandb_key = user_secrets.get_secret("WANDB_API_KEY")
    print(f"✓ WANDB_API_KEY loaded: {len(wandb_key)} characters")
except Exception as e:
    print(f"❌ Error loading WANDB_API_KEY: {e}")
    print("   Make sure you've added this secret in Kaggle Account Settings")
    wandb_key = ""

try:
    ngrok_token = user_secrets.get_secret("NGROK_TOKEN")
    print(f"✓ NGROK_TOKEN loaded: {len(ngrok_token)} characters")
except Exception as e:
    print(f"❌ Error loading NGROK_TOKEN: {e}")
    print("   Make sure you've added this secret in Kaggle Account Settings")
    ngrok_token = ""

# Validate secrets were loaded
if not dvc_json or not wandb_key or not ngrok_token:
    print("\n❌ FAILED: One or more secrets are missing!")
    print("\nPlease check:")
    print("  1. Go to Kaggle Account Settings → Secrets")
    print("  2. Add secrets with EXACT names:")
    print("     - DVC_SERVICE_ACCOUNT_JSON")
    print("     - WANDB_API_KEY")
    print("     - NGROK_TOKEN")
    print("  3. Make sure 'Add-ons' are enabled for this notebook")
else:
    # Expose as environment variables
    os.environ["KAGGLE_SECRET_DVC_JSON"] = dvc_json
    os.environ["KAGGLE_SECRET_WANDB_KEY"] = wandb_key
    os.environ["KAGGLE_SECRET_NGROK_TOKEN"] = ngrok_token

    # Persist to .bashrc for SSH sessions
    # Use base64 encoding to avoid bash injection vulnerabilities
    import base64

    dvc_json_b64 = base64.b64encode(dvc_json.encode()).decode()
    wandb_key_b64 = base64.b64encode(wandb_key.encode()).decode()
    ngrok_token_b64 = base64.b64encode(ngrok_token.encode()).decode()

    with open("/root/.bashrc", "a") as f:
        f.write("\n# Kaggle Secrets for Training (base64-encoded for security)\n")
        f.write(f'export KAGGLE_SECRET_DVC_JSON_B64="{dvc_json_b64}"\n')
        f.write(f'export KAGGLE_SECRET_WANDB_KEY_B64="{wandb_key_b64}"\n')
        f.write(f'export KAGGLE_SECRET_NGROK_TOKEN_B64="{ngrok_token_b64}"\n')

    print("\n✅ Secrets injected successfully!")
    print(f"   - KAGGLE_SECRET_DVC_JSON: {len(dvc_json)} characters")
    print(f"   - KAGGLE_SECRET_WANDB_KEY: {len(wandb_key)} characters")
    print(f"   - KAGGLE_SECRET_NGROK_TOKEN: {len(ngrok_token)} characters")
    print("\n✓ Secrets are now available in SSH sessions")
# Out:
# Injecting Kaggle Secrets as environment variables...
# ✓ DVC_SERVICE_ACCOUNT_JSON loaded: 2398 characters
# ✓ WANDB_API_KEY loaded: 40 characters
# ✓ NGROK_TOKEN loaded: 49 characters
#
# ✅ Secrets injected successfully!
#    - KAGGLE_SECRET_DVC_JSON: 2398 characters
#    - KAGGLE_SECRET_WANDB_KEY: 40 characters
#    - KAGGLE_SECRET_NGROK_TOKEN: 49 characters
#
# ✓ Secrets are now available in SSH sessions

# %% [markdown]
# ## Cell 4: Start ngrok Tunnel (Keep Running!)
#
# ⚠️ **IMPORTANT:** This cell will run indefinitely. Keep this notebook running!

# %%
print("=" * 60)
print("Starting ngrok tunnel...")
print("=" * 60)
print("")
print("INSTRUCTIONS:")
print("1. Copy the SSH command from output below")
print("2. Connect via SSH from your local machine:")
print("")
print("   ssh root@<ngrok-host> -p <port>")
print(f"   Password: {SSH_PASSWORD}")
print("")
print("3. Or connect via VS Code/Cursor Remote-SSH extension")
print("")
print("=" * 60)
print("")

# Keep tunnel alive: authenticate ngrok, start tunnel, then keep kernel alive
import os
import re
import time
import json
import datetime
import subprocess
from pathlib import Path

KEEPALIVE_SLEEP = 15  # heartbeat interval in seconds

# Get ngrok token from environment
ngrok_token = os.environ.get("KAGGLE_SECRET_NGROK_TOKEN", "")

if not ngrok_token:
    print("❌ NGROK_TOKEN not found in environment!")
    print("   Make sure Cell 3 ran successfully and the secret is configured.")
    raise SystemExit(1)

# Kill previous ngrok instances
subprocess.run(
    ["pkill", "-f", "ngrok"],
    check=False,
    stdout=subprocess.DEVNULL,
    stderr=subprocess.DEVNULL,
)

# Wait for previous instances to fully terminate (avoid race condition)
time.sleep(2)

# Authenticate ngrok
print("Authenticating ngrok...")
auth_result = subprocess.run(
    ["ngrok", "config", "add-authtoken", ngrok_token], capture_output=True, text=True
)

if auth_result.returncode != 0:
    print(f"❌ Failed to authenticate ngrok:")
    print(f"   stdout: {auth_result.stdout}")
    print(f"   stderr: {auth_result.stderr}")
    raise SystemExit(1)

print("✓ ngrok authenticated")
print(f"   Config output: {auth_result.stdout.strip()}")

# Start ngrok tunnel for SSH (port 22) - use daemon mode + API query
print("Starting ngrok tunnel on port 22...")
print("⚠️  Note: Free tier only allows 1 agent online at a time!")
print("   If you have another ngrok tunnel running, it will be disconnected.\n")

# Start ngrok in background (write logs to file)
log_file = Path("/kaggle/working/ngrok.log")
proc = subprocess.Popen(
    ["ngrok", "tcp", "22", "--log", str(log_file)],
    stdout=subprocess.DEVNULL,
    stderr=subprocess.DEVNULL,
)

# Wait for ngrok to initialize (increased for reliability)
print("Initializing ngrok...", end="", flush=True)
time.sleep(5)

if proc.poll() is not None:
    print("\n❌ ngrok died immediately! Check log:")
    print(f"   cat {log_file}")
    raise SystemExit(1)

print(" OK")

# Query ngrok API for tunnel info (more reliable than parsing stdout)
print("Querying ngrok API...", end="", flush=True)

tunnel_host = None
tunnel_port = None
timeout = 20  # seconds
start_time = time.time()

# Query ngrok local API (http://localhost:4040) for tunnel info
import urllib.request

while time.time() - start_time < timeout:
    try:
        # Check if process died
        if proc.poll() is not None:
            print("\n❌ ngrok process died!")
            print(f"   Check log: cat {log_file}")
            break

        # Query API
        response = urllib.request.urlopen(
            "http://localhost:4040/api/tunnels", timeout=2
        )
        data = json.loads(response.read().decode())

        tunnels = data.get("tunnels", [])
        for tunnel in tunnels:
            if tunnel.get("proto") == "tcp":
                public_url = tunnel.get("public_url", "")
                match = re.search(r"tcp://([^:]+):(\d+)", public_url)
                if match:
                    tunnel_host = match.group(1)
                    tunnel_port = match.group(2)
                    break

        if tunnel_host:
            break

    except Exception:
        # API not ready yet
        pass

    time.sleep(1)
    print(".", end="", flush=True)

print("")  # newline

# Report result
if not tunnel_host or not tunnel_port:
    print("⚠️  Could not retrieve tunnel URL from ngrok API")
    print("   This usually means ngrok is still initializing or there's an API issue.")
    print(f"\n💡 Solutions:")
    print(f"   1. Check ngrok dashboard: https://dashboard.ngrok.com/tunnels/agents")
    print(f"   2. Run Cell 7 (next cell) to manually query the URL")
    print(f"   3. Or check API directly: curl http://localhost:4040/api/tunnels")
    print(f"\n📁 Log file: {log_file}")
    print("\n⚠️  Note: Tunnel may still be running! Check dashboard or Cell 7.")
else:
    print("\n✅ Tunnel established! Connect via:")
    print(f"   ssh root@{tunnel_host} -p {tunnel_port}")
    print(f"   Password: {SSH_PASSWORD}")
    print("\n⚠️  KEEPING KERNEL ALIVE. DO NOT CLOSE THIS TAB!")
    print("💡 Tip: Drag this tab to a separate window and DON'T minimize it.\n")

    try:
        counter = 0
        while True:
            time.sleep(KEEPALIVE_SLEEP)

            # Check if ngrok is still running
            if proc.poll() is not None:
                print("\n❌ ngrok died unexpectedly!")
                break

            # Print heartbeat every minute
            counter += 1
            if counter % 4 == 0:  # Every 60s (15s * 4)
                timestamp = datetime.datetime.now().strftime("%H:%M:%S")
                print(f"[{timestamp}] Kernel is active... (Tunnel OK)")

    except KeyboardInterrupt:
        print("\n🛑 User interrupted.")
        proc.terminate()
    except Exception as e:
        print(f"\n❌ Error: {e}")
        proc.terminate()
# Out:
# ============================================================
# Starting ngrok tunnel...
# ============================================================
#
# INSTRUCTIONS:
# 1. Copy the SSH command from output below
# 2. Connect via SSH from your local machine:
#
#    ssh root@<ngrok-host> -p <port>
#    Password: onb4l44pb5PHr9Eq0GNvQw
#
# 3. Or connect via VS Code/Cursor Remote-SSH extension
#
# ============================================================
#
# Authenticating ngrok...
# ✓ ngrok authenticated
#    Config output: Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml
# Starting ngrok tunnel on port 22...
# ⚠️  Note: Free tier only allows 1 agent online at a time!
#    If you have another ngrok tunnel running, it will be disconnected.
#
# Initializing ngrok... OK
# Querying ngrok API...
#
# ✅ Tunnel established! Connect via:
#    ssh root@8.tcp.ngrok.io -p 15193
#    Password: onb4l44pb5PHr9Eq0GNvQw
#
# ⚠️  KEEPING KERNEL ALIVE. DO NOT CLOSE THIS TAB!
# 💡 Tip: Drag this tab to a separate window and DON'T minimize it.
#
# [14:05:07] Kernel is active... (Tunnel OK)
# [14:06:07] Kernel is active... (Tunnel OK)
# [14:07:07] Kernel is active... (Tunnel OK)
# [14:08:07] Kernel is active... (Tunnel OK)
# [14:09:07] Kernel is active... (Tunnel OK)
# [14:10:07] Kernel is active... (Tunnel OK)
# [14:11:07] Kernel is active... (Tunnel OK)
# [14:12:07] Kernel is active... (Tunnel OK)
# [14:13:07] Kernel is active... (Tunnel OK)
# [14:14:07] Kernel is active... (Tunnel OK)
# [14:15:07] Kernel is active... (Tunnel OK)
# [14:16:07] Kernel is active... (Tunnel OK)
# [14:17:07] Kernel is active... (Tunnel OK)
# [14:18:07] Kernel is active... (Tunnel OK)
# [14:19:07] Kernel is active... (Tunnel OK)
# [14:20:07] Kernel is active... (Tunnel OK)
# [14:21:07] Kernel is active... (Tunnel OK)
# [14:22:07] Kernel is active... (Tunnel OK)
# [14:23:07] Kernel is active... (Tunnel OK)
# [14:24:07] Kernel is active... (Tunnel OK)
# [14:25:07] Kernel is active... (Tunnel OK)
# [14:26:07] Kernel is active... (Tunnel OK)
# [14:27:07] Kernel is active... (Tunnel OK)
# [14:28:07] Kernel is active... (Tunnel OK)
# [14:29:07] Kernel is active... (Tunnel OK)
# [14:30:07] Kernel is active... (Tunnel OK)
# [14:31:07] Kernel is active... (Tunnel OK)
# [14:32:07] Kernel is active... (Tunnel OK)
# [14:33:07] Kernel is active... (Tunnel OK)
# [14:34:07] Kernel is active... (Tunnel OK)
# [14:35:07] Kernel is active... (Tunnel OK)
# [14:36:07] Kernel is active... (Tunnel OK)
# [14:37:07] Kernel is active... (Tunnel OK)
# [14:38:07] Kernel is active... (Tunnel OK)
# [14:39:07] Kernel is active... (Tunnel OK)
# [14:40:07] Kernel is active... (Tunnel OK)
# [14:41:07] Kernel is active... (Tunnel OK)
# [14:42:07] Kernel is active... (Tunnel OK)
# [14:43:07] Kernel is active... (Tunnel OK)
# [14:44:07] Kernel is active... (Tunnel OK)
# [14:45:07] Kernel is active... (Tunnel OK)
# [14:46:07] Kernel is active... (Tunnel OK)
# [14:47:07] Kernel is active... (Tunnel OK)
# [14:48:07] Kernel is active... (Tunnel OK)
# [14:49:07] Kernel is active... (Tunnel OK)
# [14:50:07] Kernel is active... (Tunnel OK)
# [14:51:07] Kernel is active... (Tunnel OK)
# [14:52:07] Kernel is active... (Tunnel OK)
# [14:53:07] Kernel is active... (Tunnel OK)
# [14:54:07] Kernel is active... (Tunnel OK)
# [14:55:07] Kernel is active... (Tunnel OK)
# [14:56:07] Kernel is active... (Tunnel OK)
# [14:57:07] Kernel is active... (Tunnel OK)
# [14:58:07] Kernel is active... (Tunnel OK)
# [14:59:07] Kernel is active... (Tunnel OK)
# [15:00:07] Kernel is active... (Tunnel OK)
# [15:01:07] Kernel is active... (Tunnel OK)
# [15:02:07] Kernel is active... (Tunnel OK)
# [15:03:07] Kernel is active... (Tunnel OK)
# [15:04:07] Kernel is active... (Tunnel OK)
# [15:05:07] Kernel is active... (Tunnel OK)
# [15:06:07] Kernel is active... (Tunnel OK)
# [15:07:07] Kernel is active... (Tunnel OK)
# [15:08:07] Kernel is active... (Tunnel OK)
# [15:09:07] Kernel is active... (Tunnel OK)
# [15:10:07] Kernel is active... (Tunnel OK)
# [15:11:07] Kernel is active... (Tunnel OK)
# [15:12:07] Kernel is active... (Tunnel OK)
# [15:13:07] Kernel is active... (Tunnel OK)
# [15:14:07] Kernel is active... (Tunnel OK)
# [15:15:07] Kernel is active... (Tunnel OK)
# [15:16:07] Kernel is active... (Tunnel OK)
# [15:17:07] Kernel is active... (Tunnel OK)
# [15:18:07] Kernel is active... (Tunnel OK)
# [15:19:07] Kernel is active... (Tunnel OK)
# [15:20:07] Kernel is active... (Tunnel OK)
# [15:21:07] Kernel is active... (Tunnel OK)
# [15:22:07] Kernel is active... (Tunnel OK)
# [15:23:07] Kernel is active... (Tunnel OK)
# [15:24:07] Kernel is active... (Tunnel OK)
# [15:25:07] Kernel is active... (Tunnel OK)
# [15:26:07] Kernel is active... (Tunnel OK)
# [15:27:07] Kernel is active... (Tunnel OK)
# [15:28:07] Kernel is active... (Tunnel OK)
# [15:29:07] Kernel is active... (Tunnel OK)
# [15:30:07] Kernel is active... (Tunnel OK)
# [15:31:07] Kernel is active... (Tunnel OK)
# [15:32:07] Kernel is active... (Tunnel OK)
# [15:33:07] Kernel is active... (Tunnel OK)
# [15:34:07] Kernel is active... (Tunnel OK)
# [15:35:07] Kernel is active... (Tunnel OK)
# [15:36:07] Kernel is active... (Tunnel OK)
# [15:37:07] Kernel is active... (Tunnel OK)
# [15:38:07] Kernel is active... (Tunnel OK)
# [15:39:07] Kernel is active... (Tunnel OK)
# [15:40:07] Kernel is active... (Tunnel OK)
# [15:41:07] Kernel is active... (Tunnel OK)
# [15:42:07] Kernel is active... (Tunnel OK)
# [15:43:07] Kernel is active... (Tunnel OK)
# [15:44:07] Kernel is active... (Tunnel OK)
# [15:45:07] Kernel is active... (Tunnel OK)
# [15:46:07] Kernel is active... (Tunnel OK)
# [15:47:07] Kernel is active... (Tunnel OK)
# [15:48:07] Kernel is active... (Tunnel OK)
# [15:49:07] Kernel is active... (Tunnel OK)
# [15:50:07] Kernel is active... (Tunnel OK)
# [15:51:07] Kernel is active... (Tunnel OK)
# [15:52:07] Kernel is active... (Tunnel OK)
# [15:53:07] Kernel is active... (Tunnel OK)
# [15:54:07] Kernel is active... (Tunnel OK)
# [15:55:07] Kernel is active... (Tunnel OK)
# [15:56:07] Kernel is active... (Tunnel OK)
# [15:57:07] Kernel is active... (Tunnel OK)
# [15:58:07] Kernel is active... (Tunnel OK)
# [15:59:07] Kernel is active... (Tunnel OK)
# [16:00:07] Kernel is active... (Tunnel OK)
# [16:01:07] Kernel is active... (Tunnel OK)
# [16:02:07] Kernel is active... (Tunnel OK)
# [16:03:07] Kernel is active... (Tunnel OK)
# [16:04:07] Kernel is active... (Tunnel OK)
# [16:05:07] Kernel is active... (Tunnel OK)
# [16:06:07] Kernel is active... (Tunnel OK)
# [16:07:07] Kernel is active... (Tunnel OK)
# [16:08:07] Kernel is active... (Tunnel OK)
# [16:09:07] Kernel is active... (Tunnel OK)
# [16:10:07] Kernel is active... (Tunnel OK)
# [16:11:07] Kernel is active... (Tunnel OK)
# [16:12:07] Kernel is active... (Tunnel OK)
# [16:13:07] Kernel is active... (Tunnel OK)
# [16:14:07] Kernel is active... (Tunnel OK)
# [16:15:07] Kernel is active... (Tunnel OK)
# [16:16:07] Kernel is active... (Tunnel OK)
# [16:17:07] Kernel is active... (Tunnel OK)
# [16:18:07] Kernel is active... (Tunnel OK)
# [16:19:07] Kernel is active... (Tunnel OK)
# [16:20:07] Kernel is active... (Tunnel OK)
# [16:21:07] Kernel is active... (Tunnel OK)
# [16:22:07] Kernel is active... (Tunnel OK)
# [16:23:07] Kernel is active... (Tunnel OK)
# [16:24:07] Kernel is active... (Tunnel OK)
# [16:25:07] Kernel is active... (Tunnel OK)
# [16:26:07] Kernel is active... (Tunnel OK)
# [16:27:07] Kernel is active... (Tunnel OK)
# [16:28:07] Kernel is active... (Tunnel OK)
# [16:29:07] Kernel is active... (Tunnel OK)
# [16:30:07] Kernel is active... (Tunnel OK)
# [16:31:07] Kernel is active... (Tunnel OK)
# [16:32:07] Kernel is active... (Tunnel OK)
# [16:33:07] Kernel is active... (Tunnel OK)
# [16:34:07] Kernel is active... (Tunnel OK)
# [16:35:07] Kernel is active... (Tunnel OK)
# [16:36:07] Kernel is active... (Tunnel OK)
# [16:37:07] Kernel is active... (Tunnel OK)
# [16:38:07] Kernel is active... (Tunnel OK)
# [16:39:07] Kernel is active... (Tunnel OK)
# [16:40:07] Kernel is active... (Tunnel OK)
# [16:41:07] Kernel is active... (Tunnel OK)
# [16:42:07] Kernel is active... (Tunnel OK)
# [16:43:07] Kernel is active... (Tunnel OK)
# [16:44:07] Kernel is active... (Tunnel OK)
# [16:45:07] Kernel is active... (Tunnel OK)
# [16:46:07] Kernel is active... (Tunnel OK)
# [16:47:07] Kernel is active... (Tunnel OK)
# [16:48:07] Kernel is active... (Tunnel OK)
# [16:49:07] Kernel is active... (Tunnel OK)
# [16:50:07] Kernel is active... (Tunnel OK)
# [16:51:07] Kernel is active... (Tunnel OK)
# [16:52:07] Kernel is active... (Tunnel OK)
# [16:53:07] Kernel is active... (Tunnel OK)
# [16:54:07] Kernel is active... (Tunnel OK)
# [16:55:07] Kernel is active... (Tunnel OK)
# [16:56:07] Kernel is active... (Tunnel OK)
# [16:57:07] Kernel is active... (Tunnel OK)
# [16:58:07] Kernel is active... (Tunnel OK)
# [16:59:07] Kernel is active... (Tunnel OK)
# [17:00:07] Kernel is active... (Tunnel OK)
# [17:01:07] Kernel is active... (Tunnel OK)
# [17:02:07] Kernel is active... (Tunnel OK)
# [17:03:07] Kernel is active... (Tunnel OK)
# [17:04:07] Kernel is active... (Tunnel OK)
# [17:05:07] Kernel is active... (Tunnel OK)
# [17:06:07] Kernel is active... (Tunnel OK)
# [17:07:07] Kernel is active... (Tunnel OK)
# [17:08:07] Kernel is active... (Tunnel OK)
# [17:09:07] Kernel is active... (Tunnel OK)
# [17:10:07] Kernel is active... (Tunnel OK)
# [17:11:07] Kernel is active... (Tunnel OK)
# [17:12:07] Kernel is active... (Tunnel OK)
# [17:13:07] Kernel is active... (Tunnel OK)
# [17:14:07] Kernel is active... (Tunnel OK)
# [17:15:07] Kernel is active... (Tunnel OK)
# [17:16:07] Kernel is active... (Tunnel OK)
# [17:17:07] Kernel is active... (Tunnel OK)
# [17:18:07] Kernel is active... (Tunnel OK)
# [17:19:07] Kernel is active... (Tunnel OK)
# [17:20:07] Kernel is active... (Tunnel OK)
# [17:21:07] Kernel is active... (Tunnel OK)
# [17:22:07] Kernel is active... (Tunnel OK)
# [17:23:07] Kernel is active... (Tunnel OK)
# [17:24:07] Kernel is active... (Tunnel OK)
# [17:25:07] Kernel is active... (Tunnel OK)
# [17:26:07] Kernel is active... (Tunnel OK)
# [17:27:07] Kernel is active... (Tunnel OK)
# [17:28:07] Kernel is active... (Tunnel OK)
# [17:29:07] Kernel is active... (Tunnel OK)
# [17:30:07] Kernel is active... (Tunnel OK)
# [17:31:07] Kernel is active... (Tunnel OK)
# [17:32:07] Kernel is active... (Tunnel OK)
# [17:33:07] Kernel is active... (Tunnel OK)
# [17:34:07] Kernel is active... (Tunnel OK)
# [17:35:07] Kernel is active... (Tunnel OK)
# [17:36:07] Kernel is active... (Tunnel OK)
# [17:37:07] Kernel is active... (Tunnel OK)
# [17:38:07] Kernel is active... (Tunnel OK)
# [17:39:07] Kernel is active... (Tunnel OK)
# [17:40:07] Kernel is active... (Tunnel OK)
# [17:41:07] Kernel is active... (Tunnel OK)
# [17:42:07] Kernel is active... (Tunnel OK)
# [17:43:07] Kernel is active... (Tunnel OK)
# [17:44:07] Kernel is active... (Tunnel OK)
#
# 🛑 User interrupted.

# %% [markdown]
# ## Get Tunnel URL (if Cell 6 hangs)
#
# If the previous cell is stuck at "Waiting for tunnel URL...", run this cell to get the URL from ngrok API.

# %%
import json
import urllib.request

try:
    # Query ngrok local API
    response = urllib.request.urlopen("http://localhost:4040/api/tunnels", timeout=5)
    data = json.loads(response.read().decode())

    tunnels = data.get("tunnels", [])

    if not tunnels:
        print("❌ No active tunnels found!")
        print("   ngrok may still be starting up. Wait 5-10 seconds and try again.")
    else:
        print("✅ Active tunnels:")
        for tunnel in tunnels:
            proto = tunnel.get("proto", "")
            public_url = tunnel.get("public_url", "")

            if proto == "tcp" and "ngrok.io" in public_url:
                # Parse tcp://host:port
                import re

                match = re.search(r"tcp://([^:]+):(\d+)", public_url)
                if match:
                    host = match.group(1)
                    port = match.group(2)
                    print(f"\n🔗 SSH Connection:")
                    print(f"   ssh root@{host} -p {port}")
                    print(f"   Password: kaggle2024")
                    print(f"\n📋 For VS Code/Cursor Remote-SSH, add to ~/.ssh/config:")
                    print(f"   Host kaggle-gpu")
                    print(f"       HostName {host}")
                    print(f"       User root")
                    print(f"       Port {port}")
                    print(f"       StrictHostKeyChecking no")
                else:
                    print(f"   {proto}: {public_url}")
            else:
                print(f"   {proto}: {public_url}")

except urllib.error.URLError as e:
    print("❌ Cannot connect to ngrok API (http://localhost:4040)")
    print("   This means ngrok is not running or not ready yet.")
    print(f"   Error: {e}")
except Exception as e:
    print(f"❌ Error: {e}")
